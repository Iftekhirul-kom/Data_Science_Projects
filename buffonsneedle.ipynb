# %% [markdown]
# <a href="https://colab.research.google.com/github/Iftekhirul-kom/Data_Science_Projects/blob/main/buffonsneedle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt


d = int(input("Enter the distance betweem two lines: "))
# l must be same as d or less than d
l = int(input("Enter the needle length which must be same or less than d: "))

n = [500,1000,5000]
hits = 0
# Out:
# Enter the distance betweem two lines: 1
# Enter the needle length which must be same or less than d: 1

# %%
#Features and label
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
y.value_counts()

# %%
D_hits = []
theta_hits = []
D_miss = []
theta_miss = []

# %%
for each in n:
  D_hits.clear()
  theta_hits.clear()
  D_miss.clear()
  theta_miss.clear()
  for i in range(each):
      D = np.random.uniform(0,(d/2))
      theta = np.random.uniform(0,3.1416)

      if D <= (l/2)*math.sin(theta):
          D_hits.append(D)
          theta_hits.append(theta)
          hits += 1
      else:
          D_miss.append(D)
          theta_miss.append(theta)

  PI = (2*l)/d * each/hits
  print(PI)

  plt.figure()
  plt.scatter(theta_hits, D_hits, color="green", label="Hit")
  plt.scatter(theta_miss, D_miss, color="red", label="Miss")
  plt.legend(loc=1)
# Out:
# 3.1055900621118013
# 2.109704641350211
# 2.43842965130456
