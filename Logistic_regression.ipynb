# %% [markdown]
# <a href="https://colab.research.google.com/github/Iftekhirul-kom/Data_Science_Projects/blob/main/Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import numpy as np
iris = datasets.load_iris()
X = iris.data[:, :2]
y = (iris.target != 0) * 1

print(X.shape)   # X features
print(y.shape)   # y - Label
print(X)

# %%
import random
from random import uniform
train_set = np.array([])
val_set = np.array([])
test_set = np.array([])

#Data = np.concatenate((X,y[:,None]),axis=1)
np.random.shuffle(X)
for S in X:
  R = uniform(0,1)
  if R>=0 and R<=0.7:
    np.append(train_set, S)
  elif R>0.7 and R<=0.85:
    np.append(val_set, S)
  else:
    np.append(test_set, S)

# %%
for S in train_set,val_set,test_set:
  x = S[:2]
  np.concatenate(([1], x), axis = 0)
# Out:
# array([], dtype=float64)

# %%
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
theta = np.random.uniform(low=0.0, high=1.0, size=(3))
train_loss = []
tj = 0
lr = [0.1,0.01,0.001,0.0001,0.00001]
lr = np.array(lr)
for i in lr:
  #Traininng_Theta
  for i in range(1,1000):
    tj = 0
    for S in train_set:
      z = np.dot(x,theta)
      h = sigmoid(z)
      j = (- y*np.log(h)) - ((1-y)*np.log(1-y))
      tj = tj + j
      dv = x*(h-y)
      theta = theta - (dv * lr)
    try:
       tj = tj / len(train_set)
    except ZeroDivisionError:
       tj = 0

    train_loss.append(tj)

train_loss

# %%
# Validation
correct = 0
for S in val_set:
  z = np.dot(x,theta)
  h = sigmoid(z)
  if h >= 0.5:
    h = 1
  else:
    h = 0
  if h == y:
    correct += 1
val_acc = correcr / len(val_set) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a52bb44e32c0> in <module>()
#       1 # Validation
#       2 correct = 0
# ----> 3 for S in Val_set:
#       4   z = np.dot(x,theta)
#       5   h = sigmoid(z)
#
# NameError: name 'Val_set' is not defined

# %%
# Test accuracy
correct = 0
for S in test_set:
  z = np.dot(x,theta)
  h = sigmoid(z)
  if h >= 0.5:
    h = 1
  else:
    h = 0
  if h == y:
    correct += 1

Test_acc = correct / len(test_set) * 100
